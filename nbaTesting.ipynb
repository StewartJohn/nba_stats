# %%
import pandas as pd

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        28.0
# 9     203076   2021-22        00  1610612747               LAL        29.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# ...

# %%
from nba_api.stats.endpoints import leaguestandings
# leaguestandings
standings = leaguestandings.LeagueStandings(season='2021-22')
standings_df = standings.get_data_frames()[0]
standings_df
# Out:
#    LeagueID SeasonID      TeamID       TeamCity       TeamName Conference  \
# 0        00    22021  1610612756        Phoenix           Suns       West
# 1        00    22021  1610612748          Miami           Heat       East
# 2        00    22021  1610612738         Boston        Celtics       East
# 3        00    22021  1610612763        Memphis      Grizzlies       West
# 4        00    22021  1610612744   Golden State       Warriors       West
# 5        00    22021  1610612749      Milwaukee          Bucks       East
# 6        00    22021  1610612755   Philadelphia          76ers       East
# 7        00    22021  1610612742         Dallas      Mavericks       West
# 8        00    22021  1610612761        Toronto        Raptors       East
# 9        00    22021  1610612762           Utah           Jazz       West
# 10       00    22021  1610612741        Chicago          Bulls       East
# 11       00    22021  1610612743         Denver        Nuggets       West
# ...

# %%
#Finding a team's wins
nuggets_wins = standings_df.loc[standings_df['TeamName'] == 'Nuggets', 'WINS'].iloc[0]
nuggets_wins
# Out:
# 48

# %%
#Reset the dataframe index to team name to mak it easier to look up wins and losses
standings_dup = standings_df
standings_dup.set_index(['TeamName'], inplace = True)
standings_dup
# Out:
#               LeagueID SeasonID      TeamID       TeamCity Conference  \
# TeamName
# Suns                00    22021  1610612756        Phoenix       West
# Heat                00    22021  1610612748          Miami       East
# Celtics             00    22021  1610612738         Boston       East
# Grizzlies           00    22021  1610612763        Memphis       West
# Warriors            00    22021  1610612744   Golden State       West
# Bucks               00    22021  1610612749      Milwaukee       East
# 76ers               00    22021  1610612755   Philadelphia       East
# Mavericks           00    22021  1610612742         Dallas       West
# Raptors             00    22021  1610612761        Toronto       East
# Jazz                00    22021  1610612762           Utah       West
# Bulls               00    22021  1610612741        Chicago       East
# Nuggets             00    22021  1610612743         Denver       West
# ...

# %%
#How to find a teams wins or losses
print('Pistons won ', standings_dup.at['Pistons', 'WINS'], ' and lost ', standings_dup.at['Pistons', 'LOSSES'])
# Out:
# Pistons won  23  and lost  59

# %%
#Define one of our players scores by adding all of their pickes together
ryan_score = standings_dup.at['Pistons', 'LOSSES'] + standings_dup.at['76ers', 'WINS']
ryan_score
# Out:
# 110
